# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

# %%
with open('save/CliffWalk.pkl', 'rb') as fp:
    unpickler = pickle.Unpickler(fp)
    CW_var = unpickler.load()
x=CW_var['E']
y=CW_var['t']
plt.figure(figsize=(6,5))
plt.plot(x,y)
plt.ylabel('Episode Length',fontsize=20)
plt.xlabel('Episode',fontsize=20)
plt.axhline(y=12, linewidth=4, color='r')
plt.tight_layout()
plt.savefig('Cliff_walk.png',dpi=100, background='Transparent')
plt.show()

# %%
with open('save/CartPole.pkl', 'rb') as fp:
    unpickler = pickle.Unpickler(fp)
    CW_var = unpickler.load()
x=CW_var['E']
y=CW_var['t']
plt.figure(figsize=(6,5))
plt.plot(x,y)
plt.ylabel('Episode Length',fontsize=20)
plt.xlabel('Episode',fontsize=20)
plt.tight_layout()
plt.savefig('Cart-pole.png',dpi=100, background='Transparent')
plt.show()

# %%
with open('Assault-v0.pkl', 'rb') as fp:
    unpickler = pickle.Unpickler(fp)
    CW_var = unpickler.load()
x=CW_var['e']
y=CW_var['elength']
plt.figure(figsize=(6,5))
plt.plot(x,y)
plt.ylabel('Episode Length',fontsize=20)
plt.xlabel('Episode',fontsize=20)
plt.tight_layout()
plt.savefig('Assault-v0.png',dpi=100, background='Transparent')
plt.show()


x=CW_var['e']
y=CW_var['Loss']
plt.figure(figsize=(6,5))
plt.plot(x,y)
plt.ylabel('Episode Length',fontsize=20)
plt.xlabel('Episode',fontsize=20)
plt.tight_layout()
plt.savefig('Assault-v0.png',dpi=100, background='Transparent')
plt.show()

# %%
CW_var['R']
# Out:
# [0.0,
#  84.0,
#  21.0,
#  21.0,
#  126.0,
#  84.0,
#  42.0,
#  84.0,
#  0.0,
#  42.0,
#  0.0,
#  42.0,
#  0.0,
#  0.0,
#  126.0,
#  63.0,
#  105.0,
#  21.0,
#  63.0,
#  21.0,
#  63.0,
#  21.0,
#  21.0,
#  0.0,
#  0.0,
#  42.0,
#  63.0,
#  63.0,
#  105.0,
#  42.0,
#  84.0,
#  21.0,
#  105.0,
#  42.0,
#  21.0,
#  105.0,
#  63.0,
#  0.0,
#  0.0,
#  0.0,
#  147.0,
#  63.0,
#  84.0,
#  63.0,
#  42.0,
#  42.0,
#  63.0,
#  21.0,
#  42.0,
#  0.0,
#  42.0,
#  0.0,
#  42.0,
#  63.0,
#  42.0,
#  0.0,
#  63.0,
#  42.0,
#  84.0,
#  63.0,
#  63.0,
#  0.0,
#  21.0,
#  0.0,
#  84.0,
#  63.0,
#  105.0,
#  42.0,
#  105.0,
#  21.0,
#  21.0,
#  21.0,
#  84.0,
#  126.0,
#  21.0,
#  21.0,
#  63.0,
#  63.0,
#  105.0,
#  63.0,
#  42.0,
#  63.0,
#  42.0,
#  105.0,
#  21.0,
#  168.0,
#  42.0,
#  42.0,
#  0.0,
#  42.0,
#  63.0,
#  21.0,
#  42.0,
#  21.0,
#  105.0,
#  21.0,
#  21.0,
#  42.0,
#  84.0,
#  42.0,
#  42.0,
#  21.0,
#  63.0,
#  63.0,
#  42.0,
#  126.0,
#  42.0,
#  84.0,
#  63.0,
#  42.0,
#  84.0,
# ...
